# %% [markdown]
# # Project

# %% [markdown]
# # Final Project - Analyzing Sales Data
#
# **Date**: 29 May 2024
#
# **Author**: Thaksin Saeteaw
#
# **Course**: `Pandas Foundation`

# %%
# import data
import pandas as pd
df = pd.read_csv("sample_store.csv")

# %%
# preview top 5 rows
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# shape of dataframe
df.shape
# Out:
# (9994, 21)

# %%
# see data frame information using .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   object
#  3   Ship Date       9994 non-null   object
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
# ...

# %% [markdown]
# We can use `pd.to_datetime()` function to convert columns 'Order Date' and 'Ship Date' to datetime.

# %%
# example of pd.to_datetime() function
pd.to_datetime(df['Order Date'].head(), format='%m/%d/%Y')
# Out:
# <pre>0   2019-11-08
# 1   2019-11-08
# 2   2019-06-12
# 3   2018-10-11
# 4   2018-10-11
# Name: Order Date, dtype: datetime64[ns]</pre>

# %%
# TODO - convert order date and ship date to datetime in the original dataframe
df[['Order Date','Ship Date']] = df[['Order Date','Ship Date']].apply(pd.to_datetime, format='%m/%d/%Y')
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# TODO - count nan in postal code column
df['Postal Code'].isna().sum()
# Out:
# 11

# %%
# TODO - filter rows with missing values
df[df['Postal Code'].isna()].reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# TODO - Explore this dataset on your owns, ask your own questions

# Find the total sales grouped by Category.
Sales = df.groupby('Category')['Sales'].sum()
df1 = pd.DataFrame(Sales)
df1.round(2).reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Furniture</td>
#       <td>741999.80</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Office Supplies</td>
#       <td>719047.03</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Technology</td>
#       <td>836154.03</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Data Analysis Part
#
# Answer 10 below questions to get credit from this course. Write `pandas` code to find answers.

# %%
# TODO 01 - how many columns, rows in this dataset
df.shape
print(f'The dataset has {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# The dataset has 9994 rows and 21 columns

# %%
# TODO 02 - is there any missing values?, if there is, which colunm? how many nan values?
print(f'Yes, there are missing values in the dataset. The column "Postal Code" has 11 missing values.')
df.isna().sum().reset_index()
# Out:
# Yes, there are missing values in the dataset. The column "Postal Code" has 11 missing values.
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Row ID</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Order ID</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Order Date</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Ship Date</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Ship Mode</td>
#       <td>0</td>
#     </tr>
#     <tr>
# ...

# %%
# TODO 03 - your friend ask for `California` data, filter it and export csv for him
# --> California` data
df_california = df[ df['State'] == 'California'].reset_index()
df_california = df_california.drop('index', axis = 1)
# --> Export CSV file
df_california.to_csv("Data_California")
df_california
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# TODO 04 - your friend ask for all order data in `California` and `Texas` in 2017 (look at Order Date), send him csv file
# convert 'Order Date' into datetime format
# --> Data in `California` and `Texas` in 2017
df_cali_Taxa_2017 = df[df['State'].isin(['California', 'Texas']) & (df['Order Date'].dt.year == 2017)].reset_index()
df_cali_Taxa_2017 = df_cali_Taxa_2017.drop('index', axis = 1)
# --> Export CSV file
df_cali_Taxa_2017.to_csv("Data_California_Texas_2017")
df_cali_Taxa_2017
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# TODO 05 - how much total sales, average sales, and standard deviation of sales your company make in 2017
df_agg = df[df['Order Date'].dt.year == 2017]['Sales'].agg(['sum', 'mean', 'std']) 
print(f'In 2017, our company made total sales of {round(df_agg[0],2)}$ \
        \nThe average sales were {round(df_agg[1],2)}$, and \
        \nThe standard deviation of sales was {round(df_agg[2],2)}$')
df_agg.round(2).reset_index()
# Out:
# In 2017, our company made total sales of 484247.5$
# The average sales were 242.97$, and
# The standard deviation of sales was 754.05$
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>sum</td>
#       <td>484247.50</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>mean</td>
#       <td>242.97</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>std</td>
#       <td>754.05</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# TODO 06 - which Segment has the highest profit in 2018
df['Year'] = df['Order Date'].dt.year
df_seg_2018 = df[df['Year'] == 2018].groupby(['Year', 'Segment'])['Profit'].sum()
segment = df_seg_2018.max()
print(f'In 2018, the consumer segment had the highest profit, totaling {round(segment,2)}$')
df_seg_2018.round(2).reset_index()
# Out:
# In 2018, the consumer segment had the highest profit, totaling 28460.17$
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Segment</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018</td>
#       <td>Consumer</td>
#       <td>28460.17</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018</td>
#       <td>Corporate</td>
#       <td>20688.32</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018</td>
#       <td>Home Office</td>
#       <td>12470.11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# TODO 07 - which top 5 States have the least total sales between 15 April 2019 - 31 December 2019
df6_least_sales = df[(df['Order Date'] > '2019-04-15') & (df['Order Date'] < '2019-12-31')].groupby('State')['Sales'].sum()
df6_least_sales = df6_least_sales.sort_values(ascending=True).head(5)
least_sales_states = df6_least_sales.index

print(f'Top 5 States have the least total sales are {least_sales_states[0]}, {least_sales_states[1]}, {least_sales_states[2]}, {least_sales_states[3]}, and {least_sales_states[4]}.')
df6_least_sales.reset_index()
# Out:
# Top 5 States have the least total sales are New Hampshire, New Mexico, District of Columbia, Louisiana, and South Carolina.
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>New Hampshire</td>
#       <td>49.05</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>New Mexico</td>
#       <td>64.08</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>District of Columbia</td>
#       <td>117.07</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Louisiana</td>
#       <td>249.80</td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...

# %%
# TODO 08 - what is the proportion of total sales (%) in West + Central in 2019 e.g. 25% 
df_2019 = df[df['Order Date'].dt.year == 2019].groupby(['Region'])['Sales'].sum()
df_total_sales = (((df_2019['West'] + df_2019['Central'])/ df_2019.sum())*100).round(2)
print(f'The proportion of total sales (%) in West and Central in 2019 was {df_total_sales}%.')
df_2019.round(2).reset_index()
# Out:
# The proportion of total sales (%) in West and Central in 2019 was 54.97%.
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Region</th>
#       <th>Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Central</td>
#       <td>147429.38</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>East</td>
#       <td>180685.82</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>South</td>
#       <td>93610.22</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>West</td>
#       <td>187480.18</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# TODO 09 - find top 10 popular products in terms of number of orders vs. total sales during 2019-2020
Top_10_pop_pro = df[(df['Order Date'].dt.year >= 2019) & (df['Order Date'].dt.year <= 2020)].groupby('Product Name')['Product Name']\
    .count().sort_values(ascending = False).head(10)
print('Top 10 popular products in terms of number of orders')
print(Top_10_pop_pro)

print('--------------------------------------------------------------')

Total_sales = (df[(df['Order Date'].dt.year >= 2019) & (df['Order Date'].dt.year <= 2020)].groupby('Product Name')['Sales']\
    .sum().sort_values(ascending = False).head(10)).round(2)
print('Total sales during 2019 - 2020')
print(Total_sales)
# Out:
# Top 10 popular products in terms of number of orders
# Product Name
# Easy-staple paper                                  27
# Staples                                            24
# Staple envelope                                    22
# Staples in misc. colors                            13
# Staple remover                                     12
# Storex Dura Pro Binders                            12
# Chromcraft Round Conference Tables                 12
# Global Wood Trimmed Manager's Task Chair, Khaki    11
# Avery Non-Stick Binders                            11
# Staple-based wall hangings                         10
# Name: Product Name, dtype: int64
# --------------------------------------------------------------
# Total sales during 2019 - 2020
# Product Name
# Canon imageCLASS 2200 Advanced Copier                 61599.82
# Hewlett Packard LaserJet 3310 Copier                  16079.73
# 3D Systems Cube Printer, 2nd Generation, Magenta      14299.89
# ...

# %%
# TODO 10 - plot at least 2 plots, any plot you think interesting :)

# %%
# Plot 1 : Bar plot fore region
bar_region = df[['Region']].value_counts().plot(kind = 'bar',title='Count of region', color = ['#720026', '#ce4257', '#ff7f51', '#ff9b54'])
bar_region
# Out:
# <Axes: title={'center': 'Count of region'}, xlabel='Region'>

# %%
# Plot 2 : What is the trend of average profit per order over time?
avg_pro_per_ord = df.groupby(df['Order Date'].dt.to_period('M'))['Profit'].mean()
avg_pro_per_ord.plot(kind='line', title='Average Profit per Order Over Time', color = 'black')
# Out:
# <Axes: title={'center': 'Average Profit per Order Over Time'}, xlabel='Order Date'>

# %%
# TODO Bonus - use np.where() to create new column in dataframe to help you answer your own questions
# --> Loss of Profits
import numpy as np
df['Loss'] = np.where(df['Profit'] < 0, 'Yes', ' ')
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#       <th>Year</th>
#       <th>Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...
